# %% [markdown]
# # Streaming Data Acquisition - From Raw Stream to Clean CSV

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 1: Setup and Architecture

# %% [markdown]
# ### Install the necessary libraries:
# 1. **websocket-client**: To establish the persistent connection.
# 2. **pandas**: To process, clean, and export the collected data.

# %%
# !pip install websocket-client pandas
print("Dependencies installed successfully.")
# Out:
# Requirement already satisfied: websocket-client in /home/codespace/.local/lib/python3.12/site-packages (1.8.0)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.26.0 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.3.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/codespace/.local/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.1.1 -> 25.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Dependencies installed successfully.

# %%
## Import all required Python modules

# %%
import websocket
import json
import time
import threading
import pandas as pd
from datetime import datetime

print("Modules imported.")
# Out:
# Modules imported.

# %% [markdown]
# ### Define Global Configuration and Storage
# This cell sets the target URL and initializes the empty list that will collect all the raw messages pushed from the server.

# %%
# --- Configuration ---
# Target URL for the Binance BTC/USDT trade stream (using the stable fstream endpoint)
STREAM_URL = "wss://fstream.binance.com/ws/btcusdt@trade" 

# --- Global Storage ---
# This list will collect every single message (event) pushed by the server.
raw_data_collector = []

print(f"Target Stream URL set: {STREAM_URL}")
print("Raw data collector initialized.")
# Out:
# Target Stream URL set: wss://fstream.binance.com/ws/btcusdt@trade
# Raw data collector initialized.

# %% [markdown]
# ### Define the `on_open` Callback
# This function runs only once when the persistent connection is successfully established.

# %%
def on_open(ws):
    """Callback: Executed when the connection handshake is successful."""
    print("--- Connection Established. Starting Real-Time Data Stream ---")
    
print("on_open callback defined.")
# Out:
# on_open callback defined.

# %% [markdown]
# ### Define the `on_error` and `on_close` Callbacks
# These functions handle connection failures and the graceful shutdown of the stream.

# %%
def on_error(ws, error):
    """Callback: Executed if an error occurs during the connection."""
    print(f"--- Connection Error: {error} ---")

def on_close(ws, close_status_code, close_msg):
    """Callback: Executed when the connection is intentionally closed."""
    print("--- Connection Closed ---")
    
print("on_error and on_close callbacks defined.")
# Out:
# on_error and on_close callbacks defined.

# %% [markdown]
# ### Define the `on_message` Callback (Raw Capture Logic)
# This is the most critical function. It runs for every incoming message. For the first run, we will not filter anything.

# %%
def on_message(ws, message):
    """Callback: Executed for EVERY message pushed by the server."""
    global raw_data_collector
    
    try:
        data = json.loads(message)
        
        # 1. Store the RAW, unfiltered message dictionary
        raw_data_collector.append(data)
        
        # 2. Extract and format key fields for immediate screen output
        trade_time = datetime.fromtimestamp(data['E'] / 1000).strftime('%H:%M:%S')
        price = float(data.get('p', 0))
        volume = float(data.get('q', 0))
        
        # Print everything that comes in, including potential 0-value keep-alives
        print(f"[{trade_time}] RAW Trade: Price=${price:,.2f} | Volume={volume}")

    except Exception as e:
        # Ignore errors from malformed JSON (rare, but possible)
        pass 
    
print("on_message callback defined for RAW data capture.")
# Out:
# on_message callback defined for RAW data capture.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 2: RAW Stream Capture and Observation

# %% [markdown]
# ### Create the WebSocket Client Object

# %%
# Clear the collector list before starting a new run
raw_data_collector = []

# Create the WebSocketApp instance, linking the URL to the callback functions
ws = websocket.WebSocketApp(
    STREAM_URL,
    on_message=on_message,
    on_open=on_open,
    on_error=on_error,
    on_close=on_close
)

print("WebSocket client object created, ready to connect.")
# Out:
# WebSocket client object created, ready to connect.

# %% [markdown]
# ### Start, Run, and Close the Stream Listener
# This cell starts the connection in a separate thread and uses time.sleep() to control the duration.

# %%
print("Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.")

# Run the socket connection in a separate thread
wst = threading.Thread(target=ws.run_forever)
wst.daemon = True
wst.start()

# Hold the main thread execution for 15 seconds
time.sleep(15) 

print("Time's up. Attempting to close connection...")

# Close the connection gracefully.
ws.close() 

print(f"\nFinished RAW capture. Collected {len(raw_data_collector)} total raw messages.")
# Out:
# Starting RAW stream listener for 15 seconds. OBSERVE THE OUTPUT CAREFULLY.
# --- Connection Established. Starting Real-Time Data Stream ---
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.008
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.017
# [00:00:02] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,244.90 | Volume=0.017
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.012
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.039
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.038
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.088
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.005
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.043
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.018
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.065
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.087
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.056
# [00:00:02] RAW Trade: Price=$114,245.00 | Volume=0.023
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.015
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.056
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.011
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.005
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.088
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.003
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.353
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.177
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.631
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.207
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.01
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.142
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.275
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.008
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.009
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.04
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.005
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.02
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.008
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.012
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.003
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.026
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.1
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.008
# [00:00:03] RAW Trade: Price=$114,244.90 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.004
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.007
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:03] RAW Trade: Price=$114,245.00 | Volume=0.007
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.132
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.088
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.005
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.003
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.061
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.01
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.054
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.663
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.023
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.5
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.61
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.602
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.237
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.065
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.323
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.125
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.299
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=1.097
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=1.923
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.008
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.375
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.27
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=1.6
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.16
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.652
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.179
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.5
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.272
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.495
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.006
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.004
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.003
# [00:00:04] RAW Trade: Price=$114,244.90 | Volume=0.024
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.01
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.006
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.006
# [00:00:04] RAW Trade: Price=$114,245.00 | Volume=0.089
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.006
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.053
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.011
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.006
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.138
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.043
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.003
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.047
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.065
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.013
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.009
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.009
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.50 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,245.60 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,246.00 | Volume=0.009
# [00:00:05] RAW Trade: Price=$114,246.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,246.10 | Volume=0.155
# [00:00:05] RAW Trade: Price=$114,246.20 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,246.20 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,246.20 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,246.20 | Volume=0.027
# [00:00:05] RAW Trade: Price=$114,246.50 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,246.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,247.30 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,247.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,247.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,247.60 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,247.80 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,247.90 | Volume=0.003
# [00:00:05] RAW Trade: Price=$114,248.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.30 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.50 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.50 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.60 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.60 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.60 | Volume=0.088
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.008
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.117
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.125
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,248.60 | Volume=0.114
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.60 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.238
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.156
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.043
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.009
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.219
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.105
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.008
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.009
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.70 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.80 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.80 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.80 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.90 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,248.90 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,248.90 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,249.00 | Volume=0.523
# [00:00:05] RAW Trade: Price=$114,249.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,249.90 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,250.60 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,250.70 | Volume=0.018
# [00:00:05] RAW Trade: Price=$114,251.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,251.20 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,251.30 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,251.40 | Volume=0.026
# [00:00:05] RAW Trade: Price=$114,251.90 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,252.00 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,252.30 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,252.50 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,253.20 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,253.30 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,253.70 | Volume=0.065
# [00:00:05] RAW Trade: Price=$114,253.80 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,253.90 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,254.00 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,254.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,254.20 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,254.40 | Volume=0.008
# [00:00:05] RAW Trade: Price=$114,254.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,254.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,255.00 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,255.00 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.037
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.006
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.008
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.01
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.006
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.015
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.007
# [00:00:05] RAW Trade: Price=$114,255.60 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,255.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,255.80 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,255.90 | Volume=0.092
# [00:00:05] RAW Trade: Price=$114,255.90 | Volume=0.039
# [00:00:05] RAW Trade: Price=$114,255.90 | Volume=0.087
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.004
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.005
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,256.40 | Volume=0.003
# [00:00:05] RAW Trade: Price=$114,256.50 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,256.70 | Volume=0.001
# [00:00:05] RAW Trade: Price=$114,257.10 | Volume=0.002
# [00:00:05] RAW Trade: Price=$114,257.10 | Volume=0.008
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.805
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.5
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.278
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.61
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.314
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.372
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.04
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.045
# [00:00:06] RAW Trade: Price=$114,257.10 | Volume=0.009
# [00:00:06] RAW Trade: Price=$114,257.10 | Volume=0.011
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.003
# [00:00:06] RAW Trade: Price=$114,257.10 | Volume=0.007
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.055
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.103
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.138
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.138
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.118
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.064
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.118
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.031
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.064
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.064
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.064
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.064
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.125
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.27
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.042
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.087
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.087
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.08
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.469
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.47
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.223
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.153
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.065
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.177
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.158
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.375
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.25
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.178
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.208
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.176
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.652
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.495
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=1.0
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.005
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.514
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.5
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.014
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.006
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,257.00 | Volume=0.009
# [00:00:06] RAW Trade: Price=$114,256.90 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.90 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.90 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.60 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,256.30 | Volume=0.006
# [00:00:06] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.10 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.80 | Volume=0.006
# [00:00:06] RAW Trade: Price=$114,255.50 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.50 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,254.90 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.70 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,254.40 | Volume=0.015
# [00:00:06] RAW Trade: Price=$114,254.40 | Volume=0.07
# [00:00:06] RAW Trade: Price=$114,254.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,254.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,254.30 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.30 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.10 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,253.60 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,253.30 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,253.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,253.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,252.70 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,252.70 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,252.50 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,252.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.90 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.90 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.90 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,251.90 | Volume=0.006
# [00:00:06] RAW Trade: Price=$114,251.70 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,251.30 | Volume=0.06
# [00:00:06] RAW Trade: Price=$114,251.30 | Volume=0.003
# [00:00:06] RAW Trade: Price=$114,251.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.20 | Volume=0.478
# [00:00:06] RAW Trade: Price=$114,250.90 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,250.80 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,250.60 | Volume=0.005
# [00:00:06] RAW Trade: Price=$114,250.60 | Volume=0.067
# [00:00:06] RAW Trade: Price=$114,250.50 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.30 | Volume=0.087
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.10 | Volume=0.533
# [00:00:06] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.80 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,249.60 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.50 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,249.50 | Volume=0.027
# [00:00:06] RAW Trade: Price=$114,249.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.065
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=1.332
# [00:00:06] RAW Trade: Price=$114,249.20 | Volume=0.35
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.043
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.005
# [00:00:06] RAW Trade: Price=$114,249.30 | Volume=0.006
# [00:00:06] RAW Trade: Price=$114,249.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,249.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.60 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.60 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,249.60 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.00 | Volume=0.069
# [00:00:06] RAW Trade: Price=$114,250.00 | Volume=0.028
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,250.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.20 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,251.60 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,251.90 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,252.10 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,252.50 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,253.10 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,253.20 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,253.20 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,253.70 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.20 | Volume=0.011
# [00:00:06] RAW Trade: Price=$114,254.30 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,254.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.00 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.00 | Volume=0.059
# [00:00:06] RAW Trade: Price=$114,255.00 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,255.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,255.70 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,255.90 | Volume=0.005
# [00:00:06] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.30 | Volume=0.022
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.01
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.008
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.007
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.888
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.109
# [00:00:06] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:06] RAW Trade: Price=$114,256.30 | Volume=0.167
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.211
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.01
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.076
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.011
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.007
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.088
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.108
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.125
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.299
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.653
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.08
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.013
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.012
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.018
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.017
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.014
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.622
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.031
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.151
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.007
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.125
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.177
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.237
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.299
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.207
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.008
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.051
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.114
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.053
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.323
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=1.097
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.125
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.04
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.011
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.623
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.004
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.006
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.158
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.181
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.701
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.087
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.087
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.593
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.875
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.289
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.01
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.356
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.049
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.006
# [00:00:07] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.048
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.116
# [00:00:07] RAW Trade: Price=$114,256.40 | Volume=0.012
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.012
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.013
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.096
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.007
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.095
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.006
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.017
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.042
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.011
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.009
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.011
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.2
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.009
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.008
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.011
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.004
# [00:00:08] RAW Trade: Price=$114,256.40 | Volume=0.018
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=1.004
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.031
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.166
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.323
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.177
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.299
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.169
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.91
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.033
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.008
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.097
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.098
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.875
# [00:00:08] RAW Trade: Price=$114,256.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.006
# [00:00:08] RAW Trade: Price=$114,256.20 | Volume=0.298
# [00:00:08] RAW Trade: Price=$114,256.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,255.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,254.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,254.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,254.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,253.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,253.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,253.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,253.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,252.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,252.60 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,252.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,252.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,252.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,251.80 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,251.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,251.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,250.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,250.60 | Volume=0.005
# [00:00:08] RAW Trade: Price=$114,250.60 | Volume=0.06
# [00:00:08] RAW Trade: Price=$114,250.60 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,250.50 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,250.50 | Volume=0.533
# [00:00:08] RAW Trade: Price=$114,250.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,250.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,250.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,250.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,250.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,249.90 | Volume=0.087
# [00:00:08] RAW Trade: Price=$114,249.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,249.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,249.20 | Volume=0.25
# [00:00:08] RAW Trade: Price=$114,249.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,249.20 | Volume=0.028
# [00:00:08] RAW Trade: Price=$114,249.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,249.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,249.10 | Volume=0.027
# [00:00:08] RAW Trade: Price=$114,249.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,249.00 | Volume=0.662
# [00:00:08] RAW Trade: Price=$114,248.90 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,248.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,248.60 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,248.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,248.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,248.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,248.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,248.00 | Volume=0.05
# [00:00:08] RAW Trade: Price=$114,248.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,247.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,247.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,247.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,247.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,247.10 | Volume=0.065
# [00:00:08] RAW Trade: Price=$114,247.10 | Volume=0.087
# [00:00:08] RAW Trade: Price=$114,247.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,246.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,246.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,246.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,246.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,246.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,246.20 | Volume=0.184
# [00:00:08] RAW Trade: Price=$114,246.10 | Volume=1.225
# [00:00:08] RAW Trade: Price=$114,246.00 | Volume=0.131
# [00:00:08] RAW Trade: Price=$114,246.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.80 | Volume=0.519
# [00:00:08] RAW Trade: Price=$114,245.70 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,245.60 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.60 | Volume=1.5
# [00:00:08] RAW Trade: Price=$114,245.50 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.40 | Volume=0.478
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.318
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.017
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.52
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.10 | Volume=0.505
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=1.045
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.18
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.157
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.276
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.177
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.169
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.146
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.158
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.053
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.178
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.179
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.991
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.18
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.158
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.087
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.177
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.991
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.157
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.087
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.646
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.272
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.031
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.235
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.299
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.95
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.346
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.25
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.15
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.15
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=1.313
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=0.055
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=4.178
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.177
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.323
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.125
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=1.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.207
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.053
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.276
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.237
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.486
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=1.0
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.25
# [00:00:08] RAW Trade: Price=$114,245.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=4.48
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,244.90 | Volume=0.006
# [00:00:08] RAW Trade: Price=$114,244.80 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,244.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,244.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,244.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,243.50 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,243.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,243.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,242.70 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.60 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,242.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,242.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,241.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,241.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,240.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,240.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,240.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,240.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,240.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,239.90 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,239.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.80 | Volume=0.005
# [00:00:08] RAW Trade: Price=$114,239.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,239.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.30 | Volume=0.06
# [00:00:08] RAW Trade: Price=$114,239.30 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,239.30 | Volume=0.193
# [00:00:08] RAW Trade: Price=$114,239.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,239.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.20 | Volume=0.478
# [00:00:08] RAW Trade: Price=$114,239.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,239.00 | Volume=0.975
# [00:00:08] RAW Trade: Price=$114,238.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,238.80 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,238.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,238.70 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,238.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,238.40 | Volume=0.007
# [00:00:08] RAW Trade: Price=$114,238.20 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,238.20 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,238.10 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,237.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,237.70 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,237.60 | Volume=0.457
# [00:00:08] RAW Trade: Price=$114,237.60 | Volume=0.386
# [00:00:08] RAW Trade: Price=$114,237.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,237.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,237.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.90 | Volume=0.03
# [00:00:08] RAW Trade: Price=$114,236.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.90 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,236.60 | Volume=0.05
# [00:00:08] RAW Trade: Price=$114,236.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,236.50 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,236.40 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.40 | Volume=0.006
# [00:00:08] RAW Trade: Price=$114,236.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.30 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,236.20 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,236.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.10 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,236.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,236.00 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,235.90 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,235.90 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,235.80 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,235.60 | Volume=0.072
# [00:00:08] RAW Trade: Price=$114,235.50 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,235.50 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,235.40 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,235.40 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,235.40 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,235.40 | Volume=0.386
# [00:00:08] RAW Trade: Price=$114,235.40 | Volume=0.421
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.184
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.552
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.421
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.648
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.649
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,235.30 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,235.20 | Volume=1.061
# [00:00:08] RAW Trade: Price=$114,235.20 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,235.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,234.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,234.60 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,234.60 | Volume=0.04
# [00:00:08] RAW Trade: Price=$114,234.50 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,234.50 | Volume=0.03
# [00:00:08] RAW Trade: Price=$114,234.50 | Volume=0.005
# [00:00:08] RAW Trade: Price=$114,234.30 | Volume=0.104
# [00:00:08] RAW Trade: Price=$114,234.10 | Volume=0.018
# [00:00:08] RAW Trade: Price=$114,234.10 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,234.10 | Volume=0.421
# [00:00:08] RAW Trade: Price=$114,233.90 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,233.90 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,233.90 | Volume=0.006
# [00:00:08] RAW Trade: Price=$114,233.80 | Volume=2.282
# [00:00:08] RAW Trade: Price=$114,233.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,233.70 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,233.60 | Volume=0.002
# [00:00:08] RAW Trade: Price=$114,233.60 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,233.60 | Volume=0.785
# [00:00:08] RAW Trade: Price=$114,233.50 | Volume=0.04
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.03
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.2
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.2
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.2
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.088
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.003
# [00:00:08] RAW Trade: Price=$114,233.40 | Volume=0.04
# [00:00:08] RAW Trade: Price=$114,233.30 | Volume=0.08
# [00:00:08] RAW Trade: Price=$114,233.00 | Volume=0.001
# [00:00:08] RAW Trade: Price=$114,233.00 | Volume=0.001
# ...
# [00:00:13] RAW Trade: Price=$114,178.10 | Volume=0.001
# [00:00:13] RAW Trade: Price=$114,178.00 | Volume=0.243
# [00:00:13] RAW Trade: Price=$114,177.80 | Volume=0.073
# [00:00:13] RAW Trade: Price=$114,177.90 | Volume=0.005
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.006
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.004
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.005
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.054
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.02
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.087
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.005
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.065
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.006
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.004
# [00:00:14] RAW Trade: Price=$114,177.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,178.00 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,178.00 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,178.20 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,178.80 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,178.80 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,179.40 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,180.00 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,180.10 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,180.50 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,180.70 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,181.30 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,181.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,182.50 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,182.50 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,182.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,183.00 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.20 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.015
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.01
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.009
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.007
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.008
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.006
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.006
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.037
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.06
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.395
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.003
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.006
# [00:00:14] RAW Trade: Price=$114,183.60 | Volume=0.005
# [00:00:14] RAW Trade: Price=$114,183.70 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,183.70 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,183.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,184.30 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,184.80 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,184.80 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,184.90 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,185.50 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,186.10 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,186.20 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,186.20 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,186.20 | Volume=0.071
# [00:00:14] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=1.047
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.5
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.5
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.935
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=1.571
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.61
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.174
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.292
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.008
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.02
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.026
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.002
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.011
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.078
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.088
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.008
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.004
# [00:00:14] RAW Trade: Price=$114,187.50 | Volume=0.11
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.007
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.018
# [00:00:14] RAW Trade: Price=$114,187.60 | Volume=0.04
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.017
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.055
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.07
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.005
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.035
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.244
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=1.191
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=1.967
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.5
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.965
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.711
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.3
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.01
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.011
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.44
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.022
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.011
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.947
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.01
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.938
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.947
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.3
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.108
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.005
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.023
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.02
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.125
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.172
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.05
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.086
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.894
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.009
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.02
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.044
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.012
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.088
# [00:00:15] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.097
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.005
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.003
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.088
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.096
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.079
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.01
# [00:00:15] RAW Trade: Price=$114,187.60 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.011
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.062
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.026
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.036
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.006
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.003
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.088
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.01
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.627
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.005
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.065
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.4
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.039
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.087
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.173
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.027
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.176
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.61
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.027
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.072
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.038
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.572
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.06
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.2
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.004
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.179
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.279
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.009
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.007
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.003
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.1
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.25
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.375
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.656
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.52
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.494
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.188
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.30 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.30 | Volume=0.15
# [00:00:16] RAW Trade: Price=$114,187.30 | Volume=0.15
# [00:00:16] RAW Trade: Price=$114,187.20 | Volume=0.05
# [00:00:16] RAW Trade: Price=$114,187.20 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.00 | Volume=0.006
# [00:00:16] RAW Trade: Price=$114,187.00 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,186.90 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,186.80 | Volume=0.04
# [00:00:16] RAW Trade: Price=$114,186.80 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,186.80 | Volume=0.009
# [00:00:16] RAW Trade: Price=$114,186.40 | Volume=0.05
# [00:00:16] RAW Trade: Price=$114,186.10 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,186.10 | Volume=0.052
# [00:00:16] RAW Trade: Price=$114,185.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,185.40 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,185.30 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,185.30 | Volume=0.549
# [00:00:16] RAW Trade: Price=$114,185.20 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,185.20 | Volume=0.971
# [00:00:16] RAW Trade: Price=$114,185.00 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,185.00 | Volume=0.067
# [00:00:16] RAW Trade: Price=$114,184.80 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,184.40 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,184.10 | Volume=0.03
# [00:00:16] RAW Trade: Price=$114,184.00 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,183.90 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,183.80 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,183.80 | Volume=1.225
# [00:00:16] RAW Trade: Price=$114,183.70 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,183.60 | Volume=0.6
# [00:00:16] RAW Trade: Price=$114,183.60 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,183.50 | Volume=0.04
# [00:00:16] RAW Trade: Price=$114,183.50 | Volume=0.04
# [00:00:16] RAW Trade: Price=$114,183.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,183.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,183.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,183.00 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,182.90 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,182.80 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,182.50 | Volume=0.184
# [00:00:16] RAW Trade: Price=$114,182.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,182.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,182.30 | Volume=0.004
# [00:00:16] RAW Trade: Price=$114,182.10 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,182.00 | Volume=0.03
# [00:00:16] RAW Trade: Price=$114,181.80 | Volume=0.06
# [00:00:16] RAW Trade: Price=$114,181.80 | Volume=0.04
# [00:00:16] RAW Trade: Price=$114,181.80 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,181.70 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,181.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,181.50 | Volume=0.08
# [00:00:16] RAW Trade: Price=$114,181.40 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,181.40 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,181.40 | Volume=0.01
# [00:00:16] RAW Trade: Price=$114,181.30 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,181.20 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,181.00 | Volume=0.006
# [00:00:16] RAW Trade: Price=$114,180.90 | Volume=0.005
# [00:00:16] RAW Trade: Price=$114,180.90 | Volume=0.03
# [00:00:16] RAW Trade: Price=$114,180.90 | Volume=0.199
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.002
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.018
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.03
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.02
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.022
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.029
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.022
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.008
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.001
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.02
# [00:00:16] RAW Trade: Price=$114,187.50 | Volume=0.009
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.315
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.008
# [00:00:16] RAW Trade: Price=$114,187.60 | Volume=0.001
# Time's up. Attempting to close connection...
# --- Connection Closed ---
#
# Finished RAW capture. Collected 2668 total raw messages.

# %% [markdown]
# ### Commentary - Why the $0 Trades?
#
# --- Observation: The Data Quality Problem ---
#
# You should have observed several messages showing Price=$0.00 or Volume=0.
#
# These are **Keep-Alive (Ping/Pong) Messages**. They are network heartbeats, NOT valid trades.
#
# If we analyzed this raw data, the 0-values would skew our average price and volume calculations.
#
# Our next step is to apply a **Filter** to discard them.

# %% [markdown]
# ---

# %% [markdown]
# ## Phase 3: Data Transformation and Export

# %% [markdown]
# ### Load Raw Data into Pandas
# This is the start of the Transformation (T) phase from ETL.

# %%
# Convert the list of dictionaries collected in Phase 2 into a Pandas DataFrame
df_raw = pd.DataFrame(raw_data_collector)

print(f"DataFrame loaded with {len(df_raw)} raw messages.")
print("Raw DataFrame columns:")
print(df_raw.columns.tolist())
display(df_raw.head())
# Out:
# DataFrame loaded with 2668 raw messages.
# Raw DataFrame columns:
# ['e', 'E', 'T', 's', 't', 'p', 'q', 'X', 'm']
#        e              E              T        s           t          p      q  \
# 0  trade  1759190402646  1759190402646  BTCUSDT  6666772585  114245.00  0.001
# 1  trade  1759190402675  1759190402675  BTCUSDT  6666772586  114244.90  0.001
# 2  trade  1759190402720  1759190402720  BTCUSDT  6666772587  114245.00  0.008
# 3  trade  1759190402761  1759190402761  BTCUSDT  6666772588  114245.00  0.017
# 4  trade  1759190402763  1759190402763  BTCUSDT  6666772589  114244.90  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET   True
# 2  MARKET  False
# 3  MARKET  False
# 4  MARKET   True

# %% [markdown]
# ### Data Preparation (Type Conversion)
# The price and volume columns were read as strings or objects. We must convert them to numeric types before filtering.

# %%
# Convert price ('p') and volume ('q') columns to numeric types.
df_raw['p'] = pd.to_numeric(df_raw['p'], errors='coerce')
df_raw['q'] = pd.to_numeric(df_raw['q'], errors='coerce')

print("Price ('p') and Volume ('q') columns converted to numeric (float).")
# Out:
# Price ('p') and Volume ('q') columns converted to numeric (float).

# %% [markdown]
# ### Apply the Cleaning Filter
# This cell applies the filter to eliminate the keep-alive messages.

# %%
print(f"Messages before filtering: {len(df_raw)}")

# --- APPLY THE DATA QUALITY FILTER ---
# A valid trade must have a positive price AND a positive volume.
df_clean = df_raw[(df_raw['p'] > 0) & (df_raw['q'] > 0)].copy()

print(f"Messages after filtering: {len(df_clean)}")
print(f"Successfully filtered out {len(df_raw) - len(df_clean)} keep-alive messages.")

display(df_clean.head())
# Out:
# Messages before filtering: 2668
# Messages after filtering: 2667
# Successfully filtered out 1 keep-alive messages.
#        e              E              T        s           t         p      q  \
# 0  trade  1759190402646  1759190402646  BTCUSDT  6666772585  114245.0  0.001
# 1  trade  1759190402675  1759190402675  BTCUSDT  6666772586  114244.9  0.001
# 2  trade  1759190402720  1759190402720  BTCUSDT  6666772587  114245.0  0.008
# 3  trade  1759190402761  1759190402761  BTCUSDT  6666772588  114245.0  0.017
# 4  trade  1759190402763  1759190402763  BTCUSDT  6666772589  114244.9  0.001
#
#         X      m
# 0  MARKET  False
# 1  MARKET   True
# 2  MARKET  False
# 3  MARKET  False
# 4  MARKET   True

# %% [markdown]
# ### Add Human-Readable Columns
# The raw data uses short keys like 'E' (Event Time) and 's' (Symbol). We create descriptive columns for the final CSV.

# %%
# Convert 'E' (milliseconds since epoch) to a readable timestamp
df_clean['Trade_Time'] = pd.to_datetime(df_clean['E'], unit='ms')

# Create descriptive columns
df_clean['Price_USD'] = df_clean['p']
df_clean['Volume_BTC'] = df_clean['q']

print("Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.")
# Out:
# Human-readable columns (Trade_Time, Price_USD, Volume_BTC) created.

# %% [markdown]
# ### Select Final Columns
# Select only the essential, clean, and formatted columns for the final file.

# %%
# Select and rename final columns for a clean output structure
df_final = df_clean[['Trade_Time', 'Price_USD', 'Volume_BTC', 's']].rename(
    columns={'s': 'Symbol'}
)

print("Final DataFrame structure prepared.")
display(df_final.head())
# Out:
# Final DataFrame structure prepared.
#                Trade_Time  Price_USD  Volume_BTC   Symbol
# 0 2025-09-30 00:00:02.646   114245.0       0.001  BTCUSDT
# 1 2025-09-30 00:00:02.675   114244.9       0.001  BTCUSDT
# 2 2025-09-30 00:00:02.720   114245.0       0.008  BTCUSDT
# 3 2025-09-30 00:00:02.761   114245.0       0.017  BTCUSDT
# 4 2025-09-30 00:00:02.763   114244.9       0.001  BTCUSDT

# %% [markdown]
# ### Export to CSV
# This is the Load (L) phase of ETL.

# %%
# Define the output filename
output_filename = 'btc_usdt_stream_clean.csv'

# Export the clean DataFrame to a CSV file without the pandas index
df_final.to_csv(output_filename, index=False)

print(f"--- Load Phase Complete ---")
print(f"Clean, filtered stream data successfully exported to: {output_filename}")
# Out:
# --- Load Phase Complete ---
# Clean, filtered stream data successfully exported to: btc_usdt_stream_clean.csv
